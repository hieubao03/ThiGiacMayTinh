# %%
# import thư viện
from PIL import Image
from imgtools import *

# %%
# Đường Dẫn Ảnh
my_path = 'C:/Users/Dell/Documents/srv_cv/img/01/01.jpg'

# %%
# Đọc Ảnh
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=781x555>

# %%
# Kích Thước Ban Đầu
print(img.size)
# Out:
# (781, 555)

# %%
# Thay đổi kích thước
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Task: lưu ảnh
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Task: lưu ảnh
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x36>
